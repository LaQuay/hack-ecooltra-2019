# %%
import pandas as pd
df = pd.read_csv("hackaton_data_rentals.csv")
df.head()
# Out:
#    rental_id  start_point_lat  start_point_lon  end_point_lat  end_point_lon  \
# 0          1        41.407661         2.195133      41.427795       2.191177
# 1          2        40.431644        -3.684857      40.426453      -3.686443
# 2          3        41.884850        12.490010      41.892765      12.469176
# 3          4        41.411480         2.196850      41.411335       2.190067
# 4          5        41.396515         2.151223      41.396538       2.151235
#
#             started_at             ended_at  user_id system_name  \
# 0  2016-01-01 00:00:03  2016-01-01 00:13:02  1025384   Barcelona
# 1  2016-01-01 00:00:18  2016-01-01 01:21:41  1016632      Madrid
# 2  2016-01-01 00:00:21  2016-01-01 00:56:16  1012102        Rome
# 3  2016-01-01 00:00:33  2016-01-01 00:05:15   450334   Barcelona
# 4  2016-01-01 00:00:34  2016-01-01 00:02:07  1030150   Barcelona
#
#   vehicle_external_id                        ...                          \
# ...

# %%
df = df[df['system_name'] == 'Barcelona']
df.head()
# Out:
#    rental_id  start_point_lat  start_point_lon  end_point_lat  end_point_lon  \
# 0          1        41.407661         2.195133      41.427795       2.191177
# 3          4        41.411480         2.196850      41.411335       2.190067
# 4          5        41.396515         2.151223      41.396538       2.151235
# 8          9        41.375774         2.133490      41.375828       2.133465
# 9         10        41.396996         2.170572      41.377197       2.158820
#
#             started_at             ended_at  user_id system_name  \
# 0  2016-01-01 00:00:03  2016-01-01 00:13:02  1025384   Barcelona
# 3  2016-01-01 00:00:33  2016-01-01 00:05:15   450334   Barcelona
# 4  2016-01-01 00:00:34  2016-01-01 00:02:07  1030150   Barcelona
# 8  2016-01-01 00:00:55  2016-01-01 00:02:31  1042724   Barcelona
# 9  2016-01-01 00:01:02  2016-01-01 00:16:55   286426   Barcelona
#
#   vehicle_external_id                        ...                          \
# ...

# %%
df1000 = df[:60000]
df1000
# Out:
#         rental_id  start_point_lat  start_point_lon  end_point_lat  \
# 0               1        41.407661         2.195133      41.427795
# 3               4        41.411480         2.196850      41.411335
# 4               5        41.396515         2.151223      41.396538
# 8               9        41.375774         2.133490      41.375828
# 9              10        41.396996         2.170572      41.377197
# 10             11        41.362968         2.136852      41.374222
# 12             13        41.386372         2.150520      41.404823
# 13             14        41.386066         2.149840      41.405205
# 18             19        41.407295         2.162832      41.419193
# 20             21        41.392220         2.197610      41.384655
# 22             23        41.405739         2.138710      41.405762
# 23             24        41.385094         2.176700      41.378975
# 26             27        41.389370         2.196398      41.401508
# ...

# %%
df1000.to_csv(r'2_sem_data_rental.csv')

# %%
df1000.to_csv(r'1000_data_rental.csv')
